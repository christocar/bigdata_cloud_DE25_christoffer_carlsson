# %% [markdown]
# # in class exercise 03
# nobel data

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql
SHOW SCHEMAS IN nobel_catalog;

# %%
# %sql
LIST '/Volumes/nobel_catalog/nobel_schema/nobel_volume';

# %% [markdown]
# # Read in csv file

# %%
DATA_PATH = '/Volumes/nobel_catalog/nobel_schema/nobel_volume'

df = spark.read.csv(f"{DATA_PATH}/complete.csv", header=True, inferSchema=True)
df

# %%
df.limit(3).display()

# %%
df.take(2)
